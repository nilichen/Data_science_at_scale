# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data munging

# %%
types = {'CompetitionOpenSinceYear': np.dtype(int),
         'CompetitionOpenSinceMonth': np.dtype(int),
         'StateHoliday': np.dtype(str),
         'Promo2SinceWeek': np.dtype(int),
         'SchoolHoliday': np.dtype(int),
         'PromoInterval': np.dtype(str)}

# %%
train = pd.read_csv("train.csv", parse_dates=[2], dtype=types)

# %%
train.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test = pd.read_csv("test.csv", parse_dates=[3], dtype=types)

# %% [markdown]
# * Assume store opens, if not provided

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4 2015-09-17     1      1            0              0
# 1   2      3          4 2015-09-17     1      1            0              0
# 2   3      7          4 2015-09-17     1      1            0              0
# 3   4      8          4 2015-09-17     1      1            0              0
# 4   5      9          4 2015-09-17     1      1            0              0

# %%
store = pd.read_csv("store.csv")

# %%
sum(store.CompetitionDistance.isnull())
# Out:
# 3

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a                 1270                          9
# 1      2         a          a                  570                         11
# 2      3         a          a                14130                         12
# 3      4         c          c                  620                          9
# 4      5         a          a                29910                          4
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                      2008       0              NaN              NaN
# 1                      2007       1               13             2010
# 2                      2006       1               14             2011
# 3                      2009       0              NaN              NaN
# 4                      2015       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %% [markdown]
# * Consider only open stores for training. Closed stores wont count into the score.
# * Use only Sales bigger then zero

# %%
train = train[train["Open"] != 0]
train = train[train["Sales"] > 0]

# %%
#from sklearn.preprocessing import OneHotEncoder
newTrain = train.merge(store, on="Store")

# %%
newTrain.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      1          4 2015-07-30   5020        546     1      1            0
# 2      1          3 2015-07-29   4782        523     1      1            0
# 3      1          2 2015-07-28   5011        560     1      1            0
# 4      1          1 2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a                 1270
# 1              1         c          a                 1270
# 2              1         c          a                 1270
# 3              1         c          a                 1270
# 4              1         c          a                 1270
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                          9                      2008       0
# 1                          9                      2008       0
# 2                          9                      2008       0
# 3                          9                      2008       0
# 4                          9                      2008       0
#
#    Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3              NaN              NaN           NaN
# 4              NaN              NaN           NaN

# %%
newTest = test.merge(store, on="Store")

# %% [markdown]
# * Build new features

# %%
def build_features(features, data):
    # remove NaNs
    data.fillna(0, inplace=True)
    data.loc[data.Open.isnull(), 'Open'] = 1
    # Use some properties directly
    features.extend(['Store', 'log(CompetitionDistiance)', 'Promo', 'Promo2', 'SchoolHoliday'])
    data['log(CompetitionDistiance)'] = np.log(data.CompetitionDistance+1)
    
    # Label encode some features
    features.extend(['StoreType', 'Assortment', 'StateHoliday'])
    mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
    data.StoreType.replace(mappings, inplace=True)
    data.Assortment.replace(mappings, inplace=True)
    data.StateHoliday.replace(mappings, inplace=True)

    features.extend(['DayOfWeek', 'Month', 'Day', 'Year', 'WeekOfYear'])
    data['Date'] = pd.to_datetime(data['Date'])
    data['Year'] = data.Date.dt.year
    data['Month'] = data.Date.dt.month
    data['Day'] = data.Date.dt.day
    data['DayOfWeek'] = data.Date.dt.dayofweek
    data['WeekOfYear'] = data.Date.dt.weekofyear

    # CompetionOpen en PromoOpen from https://www.kaggle.com/ananya77041/rossmann-store-sales/randomforestpython/code
    # Calculate time competition open time in months
    features.append('CompetitionOpen')
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
        (data.Month - data.CompetitionOpenSinceMonth)
    data.loc[data.CompetitionOpenSinceYear == 0, 'CompetitionOpen'] = 0
    # Promo open time in months
    features.append('Promo2Open')
    data['Promo2Open'] = 12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0
    data['Promo2Open'] = data.Promo2Open.apply(lambda x: x if x > 0 else 0)
    data.loc[data.Promo2SinceYear == 0, 'Promo2Open'] = 0

    # Indicate that sales on that day are in promo interval
    features.append('IsPromo2Month')
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', \
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['monthStr'] = data.Month.map(month2str)
    data.loc[data.PromoInterval == 0, 'PromoInterval'] = ''
    data['IsPromo2Month'] = 0
    for interval in data.PromoInterval.unique():
        if interval != '':
            for month in interval.split(','):
                data.loc[(data.monthStr == month) & (data.PromoInterval == interval), 'IsPromo2Month'] = 1

    return data

# %%
features = []
newTrain = build_features(features, newTrain)
features
# Out:
# ['Store',
#  'log(CompetitionDistiance)',
#  'Promo',
#  'Promo2',
#  'SchoolHoliday',
#  'StoreType',
#  'Assortment',
#  'StateHoliday',
#  'DayOfWeek',
#  'Month',
#  'Day',
#  'Year',
#  'WeekOfYear',
#  'CompetitionOpen',
#  'Promo2Open',
#  'IsPromo2Month']

# %%
newTrain.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          4 2015-07-31   5263        555     1      1             0
# 1      1          3 2015-07-30   5020        546     1      1             0
# 2      1          2 2015-07-29   4782        523     1      1             0
# 3      1          1 2015-07-28   5011        560     1      1             0
# 4      1          0 2015-07-27   6102        612     1      1             0
#
#    SchoolHoliday  StoreType      ...        PromoInterval  \
# 0              1          3      ...
# 1              1          3      ...
# 2              1          3      ...
# 3              1          3      ...
# 4              1          3      ...
#
#    log(CompetitionDistiance)  Year  Month  Day  WeekOfYear  CompetitionOpen  \
# 0                   7.147559  2015      7   31          31               82
# 1                   7.147559  2015      7   30          31               82
# 2                   7.147559  2015      7   29          31               82
# 3                   7.147559  2015      7   28          31               82
# 4                   7.147559  2015      7   27          31               82
#
#   Promo2Open  monthStr  IsPromo2Month
# 0          0       Jul              0
# 1          0       Jul              0
# 2          0       Jul              0
# 3          0       Jul              0
# 4          0       Jul              0
#
# [5 rows x 27 columns]

# %%
pd.unique(newTrain.CompetitionOpenSinceYear)
# Out:
# array([ 2008.,  2007.,  2006.,  2009.,  2015.,  2013.,  2014.,  2000.,
#         2011.,     0.,  2010.,  2005.,  1999.,  2003.,  2012.,  2004.,
#         2002.,  1961.,  1995.,  2001.,  1990.,  1994.,  1900.,  1998.])

# %%
newTest = build_features([], newTest)

# %%
newTest.head()
# Out:
#      Id  Store  DayOfWeek       Date  Open  Promo  StateHoliday  \
# 0     1      1          3 2015-09-17     1      1             0
# 1   857      1          2 2015-09-16     1      1             0
# 2  1713      1          1 2015-09-15     1      1             0
# 3  2569      1          0 2015-09-14     1      1             0
# 4  3425      1          6 2015-09-13     0      0             0
#
#    SchoolHoliday  StoreType  Assortment      ...        PromoInterval  \
# 0              0          3           1      ...
# 1              0          3           1      ...
# 2              0          3           1      ...
# 3              0          3           1      ...
# 4              0          3           1      ...
#
#    log(CompetitionDistiance)  Year  Month  Day  WeekOfYear CompetitionOpen  \
# 0                   7.147559  2015      9   17          38              84
# 1                   7.147559  2015      9   16          38              84
# 2                   7.147559  2015      9   15          38              84
# 3                   7.147559  2015      9   14          38              84
# 4                   7.147559  2015      9   13          37              84
#
#    Promo2Open  monthStr  IsPromo2Month
# 0           0      Sept              0
# 1           0      Sept              0
# 2           0      Sept              0
# 3           0      Sept              0
# 4           0      Sept              0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Exploratory data analysis

# %%
np.log(newTrain['CompetitionDistance']+1).plot(kind='hist')

# %%
np.log(newTrain['Sales']).plot(kind='hist')

# %%
newTrain['Sales'].plot(kind='hist')

# %%
compdist = newTrain.groupby('CompetitionDistance')['Sales'].mean().reset_index()
compdist[compdist['CompetitionDistance']!=0].plot(x='CompetitionDistance', y='Sales', kind='scatter', logx=True, logy=True)

# %%
compdist[compdist['CompetitionDistance']!=0].plot(x='CompetitionDistance', y='Sales', kind='scatter', logx=True)

# %%
promo2 = newTrain.groupby(['Promo2', "Date"])['Sales'].mean()

# %%
promo2 = promo2.unstack(0)#.plot()

# %%
promo2.head()
# Out:
# Promo2                0            1
# Date
# 2013-01-01  6742.666667  3264.600000
# 2013-01-02  6917.536044  5627.091228
# 2013-01-03  6228.933333  5244.632689
# 2013-01-04  6403.650000  5600.322183
# 2013-01-05  5738.261596  5032.869718

# %%
#plt.figure()
promo2.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10a6e1490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10a7e10d0>], dtype=object)

# %%
promo = newTrain.groupby(["Promo", "Date"])["Sales"].mean().reset_index()

# %%
promo.head()
# Out:
#    Promo       Date        Sales
# 0      0 2013-01-01  5719.705882
# 1      0 2013-01-02  6255.471647
# 2      0 2013-01-03  5723.913436
# 3      0 2013-01-04  5991.835740
# 4      0 2013-01-05  5376.326107

# %%
from ggplot import *
ggplot(aes(x="Date", y="Sales", color="factor(Promo)"), data=promo) + geom_line()
# Out:
# <ggplot: (283035177)>

# %%
dayofweek = newTrain.groupby(["DayOfWeek","Date"])["Sales"].mean().reset_index()

# %%
dayofweek.head()
# Out:
#    DayOfWeek       Date        Sales
# 0          0 2013-01-07  9789.193490
# 1          0 2013-01-14  5327.409955
# 2          0 2013-01-21  7914.249322
# 3          0 2013-01-28  5310.480578
# 4          0 2013-02-04  9317.990081

# %%
ggplot(aes(x="Date", y="Sales"), data=dayofweek) + geom_line() + facet_wrap("DayOfWeek") + scale_y_continuous(limits = (0, 15000))
# Out:
# <ggplot: (279367281)>

# %%
storetype = newTrain.groupby(['StoreType', 'Date'])['Sales'].mean().reset_index()

# %%
ggplot(aes(x='Date', y='Sales'), data=storetype) + geom_line() + facet_wrap('StoreType') + scale_y_continuous(limits = (0, 15000))
# Out:
# <ggplot: (279367305)>

# %%
assortment = newTrain.groupby(['Assortment', 'Date'])['Sales'].mean().reset_index()
ggplot(aes(x='Date', y='Sales'), data=assortment) + geom_line() + facet_wrap('Assortment') + scale_y_continuous(limits = (0, 15000))
# Out:
# <ggplot: (287778861)>

# %%
schoolholiday = newTrain.groupby(['SchoolHoliday', 'Date'])['Sales'].mean().reset_index()
ggplot(aes(x='Date', y='Sales'), data=schoolholiday) + geom_line() + facet_wrap('SchoolHoliday') + scale_y_continuous(limits = (0, 15000))
# Out:
# <ggplot: (281776993)>

# %%
newTrain.columns
# Out:
# Index([u'Store', u'DayOfWeek', u'Date', u'Sales', u'Customers', u'Open',
#        u'Promo', u'StateHoliday', u'SchoolHoliday', u'StoreType',
#        u'Assortment', u'CompetitionDistance', u'CompetitionOpenSinceMonth',
#        u'CompetitionOpenSinceYear', u'Promo2', u'Promo2SinceWeek',
#        u'Promo2SinceYear', u'PromoInterval', u'Year', u'Month', u'Day',
#        u'WeekOfYear', u'CompetitionOpen', u'Promo2Open', u'monthStr',
#        u'IsPromo2Month'],
#       dtype='object')

# %%
newTrain[features].head()
# Out:
#    Store  log(CompetitionDistiance)  Promo  Promo2  SchoolHoliday  StoreType  \
# 0      1                   7.147559      1       0              1          3
# 1      1                   7.147559      1       0              1          3
# 2      1                   7.147559      1       0              1          3
# 3      1                   7.147559      1       0              1          3
# 4      1                   7.147559      1       0              1          3
#
#    Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0           1             0          4      7   31  2015          31
# 1           1             0          3      7   30  2015          31
# 2           1             0          2      7   29  2015          31
# 3           1             0          1      7   28  2015          31
# 4           1             0          0      7   27  2015          31
#
#    CompetitionOpen  Promo2Open  IsPromo2Month
# 0               82           0              0
# 1               82           0              0
# 2               82           0              0
# 3               82           0              0
# 4               82           0              0

# %%
newTest[features].head()
# Out:
#    Store  log(CompetitionDistiance)  Promo  Promo2  SchoolHoliday  StoreType  \
# 0      1                   7.147559      1       0              0          3
# 1      1                   7.147559      1       0              0          3
# 2      1                   7.147559      1       0              0          3
# 3      1                   7.147559      1       0              0          3
# 4      1                   7.147559      0       0              0          3
#
#    Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0           1             0          3      9   17  2015          38
# 1           1             0          2      9   16  2015          38
# 2           1             0          1      9   15  2015          38
# 3           1             0          0      9   14  2015          38
# 4           1             0          6      9   13  2015          37
#
#    CompetitionOpen  Promo2Open  IsPromo2Month
# 0               84           0              0
# 1               84           0              0
# 2               84           0              0
# 3               84           0              0
# 4               84           0              0

# %% [markdown]
# # Initial analysis: comparing different regressors

# %% [markdown]
# ### Prepare the data

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(categorical_features=[2, 3, 4, 5, 6, 7, 14, 15])
enc.fit(newTrain[features])
newTrainEncoded = enc.transform(newTrain[features].values)

# %%
newTrainEncoded
# Out:
# <844338x1214 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13365082 stored elements in COOrdinate format>

# %%
def rmspe(y, yhat):
    return np.sqrt(np.mean(((y - yhat)/y) ** 2))
def rmspe_xg(y, yhat):
    y = np.expm1(y)
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y, yhat)

# %%
from sklearn.cross_validation import train_test_split
X = newTrainEncoded
y = np.log1p(newTrain.Sales)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
print X_train.shape
print X_valid.shape
# Out:
# (675470, 100)
# (168868, 100)

# %%
def deviance_plot(est, X_test, y_test, ax=None, label='', train_color='#2c7bb6', 
                  test_color='#d7191c', alpha=1.0):
    """Deviance plot for ``est``, use ``X_test`` and ``y_test`` for test error. """
    n_estimators = len(est.estimators_)
    test_dev = np.empty(n_estimators)

    for i, pred in enumerate(est.staged_predict(X_test)):
       test_dev[i] = est.loss_(y_test, pred)

    if ax is None:
        fig = plt.figure()
        ax = plt.gca()
        
    ax.plot(np.arange(n_estimators) + 1, test_dev, color=test_color, label='Test %s' % label, 
             linewidth=2, alpha=alpha)
    ax.plot(np.arange(n_estimators) + 1, est.train_score_, color=train_color, 
             label='Train %s' % label, linewidth=2, alpha=alpha)
    ax.set_ylabel('Error')
    ax.set_xlabel('n_estimators')
    return test_dev, ax

# %% [markdown]
# ### Lasso regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_pred = lasso.predict(X_valid)
rmspe_xg(y_valid, lasso_pred)
# Out:
# ('rmspe', 0.52546584545470765)

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()
X_train = scale.fit_transform(X_train.toarray())
svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits

# %% [markdown]
# ### Random Forest Regressor
# * For tree-based methods ordinal encoding is as effective as one-hot encoding but more efficient (less memory & faster runtime) given that you grow deep enough trees:

# %%
X = newTrain[features].values
X_train0, X_valid0 = train_test_split(X, test_size=0.2, random_state=10)

# %%
X_train0
# Out:
# array([[  6.93000000e+02,   6.11146734e+00,   1.00000000e+00, ...,
#           0.00000000e+00,   3.92500000e+01,   1.00000000e+00],
#        [  8.50000000e+01,   7.53422833e+00,   1.00000000e+00, ...,
#           2.60000000e+01,   0.00000000e+00,   0.00000000e+00],
#        [  3.00000000e+02,   4.79579055e+00,   0.00000000e+00, ...,
#           5.40000000e+01,   2.22500000e+01,   1.00000000e+00],
#        ...,
#        [  5.87000000e+02,   5.80211838e+00,   0.00000000e+00, ...,
#           1.00000000e+02,   4.55000000e+01,   1.00000000e+00],
#        [  1.00800000e+03,   3.43398720e+00,   0.00000000e+00, ...,
#           5.60000000e+01,   0.00000000e+00,   0.00000000e+00],
#        [  4.57000000e+02,   9.48349239e+00,   1.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(oob_score=True)
rf.fit(X_train0, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
rf_pred = rf.predict(X_valid0)
rmspe_xg(y_valid, rf_pred)
# Out:
# ('rmspe', 0.14396049022870677)

# %%
fx_imp = pd.Series(rf.feature_importances_ , index=features)
fx_imp /= fx_imp.max()  # normalize
fx_imp.sort()
fx_imp.plot(kind='barh')
# Out:
# /Users/KatrinaNi/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   app.launch_new_instance()

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor(n_estimators=500, verbose=1, warm_start=True)
gb.fit(X_train0, y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.1735           53.56m
#          2           0.1674           44.54m
#          3           0.1624           41.96m
#          4           0.1582           40.59m
#          5           0.1548           40.19m
#          6           0.1519           39.55m
#          7           0.1494           38.88m
#          8           0.1474           38.27m
#          9           0.1457           38.01m
#         10           0.1442           37.61m
#         20           0.1354           35.68m
#         30           0.1294           33.68m
#         40           0.1253           32.57m
#         50           0.1219           31.38m
#         60           0.1197           30.44m
#         70           0.1178           29.42m
#         80           0.1148           27.58m
#         90           0.1131           25.40m
#        100           0.1114           23.44m
#        200           0.0964           12.99m
#        300           0.0846            7.64m
#        400           0.0754            3.50m
#        500           0.0670            0.00s
# GradientBoostingRegressor(alpha=0.9, init=None, learning_rate=0.1, loss='ls',
#              max_depth=3, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=500,
#              random_state=None, subsample=1.0, verbose=1, warm_start=True)

# %%
gb_predTrain = gb.predict(X_train0)
rmspe_xg(y_train, gb_predTrain)
# Out:
# ('rmspe', 0.3318751664002047)

# %%
gb_pred = gb.predict(X_valid0)
rmspe_xg(y_valid, gb_pred)
# Out:
# ('rmspe', 0.28972345374762437)

# %%
test_dev, ax = deviance_plot(gb, X_valid0, y_valid)
ax.legend(loc='upper right')

# %% [markdown]
# =======> Underfitting

# %%
gb = GradientBoostingRegressor(n_estimators=1000, subsample=0.9, verbose=1, warm_start=True)
gb.fit(X_train0, y_train)
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           0.1734           0.0075          103.88m
#          2           0.1674           0.0061           86.15m
#          3           0.1624           0.0051           79.36m
#          4           0.1582           0.0041           75.84m
#          5           0.1549           0.0033           74.54m
#          6           0.1519           0.0030           73.41m
#          7           0.1494           0.0024           73.15m
#          8           0.1476           0.0020           72.37m
#          9           0.1456           0.0018           71.91m
#         10           0.1441           0.0015           71.75m
#         20           0.1347           0.0007           68.84m
#         30           0.1286           0.0004           65.88m
#         40           0.1245           0.0004           63.97m
#         50           0.1216           0.0005           62.39m
#         60           0.1194           0.0001           60.98m
#         70           0.1176           0.0002           59.73m
#         80           0.1159           0.0001           58.59m
#         90           0.1137           0.0001           58.10m
#        100           0.1124           0.0001           56.99m
#        200           0.0968           0.0000           49.40m
#        300           0.0841           0.0001           35.69m
#        400           0.0755           0.0001           26.99m
#        500           0.0673           0.0002           20.43m
#        600           0.0601           0.0001           15.89m
#        700           0.0553           0.0001           12.98m
#        800           0.0512           0.0000            9.14m
#        900           0.0469           0.0001            4.77m
#       1000           0.0435           0.0000            0.00s
# GradientBoostingRegressor(alpha=0.9, init=None, learning_rate=0.1, loss='ls',
#              max_depth=3, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=1000,
#              random_state=None, subsample=0.9, verbose=1, warm_start=True)

# %%
gb_predTrain = gb.predict(X_train0)
rmspe_xg(y_train, gb_predTrain)
# Out:
# ('rmspe', 0.28079857071603759)

# %%
gb_pred = gb.predict(X_valid0)
rmspe_xg(y_valid, gb_pred)
# Out:
# ('rmspe', 0.23180548709120552)

# %%
test_dev, ax = deviance_plot(gb, X_valid0, y_valid)
ax.legend(loc='upper right')

# %% [markdown]
# =======> Underfitting

# %% [markdown]
# * Feature Importance

# %%
fx_imp = pd.Series(gb.feature_importances_, index=features)
fx_imp /= fx_imp.max()  # normalize
fx_imp.sort()
fx_imp.plot(kind='barh')
# Out:
# /Users/KatrinaNi/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   app.launch_new_instance()

# %% [markdown]
# # Grid search for the ensemble methods

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import grid_search
params_rf = {
              'max_depth': [5, 10, 20],
              'min_sample_leaf': [50, 100, 150]
              }
rf = RandomForestRegressor(n_estimators=100)
searchRF = grid_search.RandomizedSearchCV(rf, params_rf, scoring='mean_squared_error', n_jobs=-1, verbose=1).fit(X_train0, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed: 79.4min
# [Parallel(n_jobs=-1)]: Done  24 out of  30 | elapsed: 146.3min remaining: 36.6min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 180.9min finished
# [CV] max_features=auto, n_estimators=1000, max_depth=5 ...............
# [CV] max_features=auto, n_estimators=1000, max_depth=5 ...............
# [CV] max_features=auto, n_estimators=1000, max_depth=5 ...............
# [CV] max_features=log2, n_estimators=1000, max_depth=10 ..............
# [CV] ...... max_features=auto, n_estimators=1000, max_depth=5 -79.3min[CV] ...... max_features=auto, n_estimators=1000, max_depth=5 -80.0min[CV] ...... max_features=auto, n_estimators=1000, max_depth=5 -79.4min[CV] ..... max_features=log2, n_estimators=1000, max_depth=10 -42.3min
#
#
#
# [CV] max_features=log2, n_estimators=1000, max_depth=10 ..............[CV] max_features=sqrt, n_estimators=100, max_depth=5 ................[CV] max_features=sqrt, n_estimators=100, max_depth=5 ................[CV] max_features=log2, n_estimators=1000, max_depth=10 ..............
#
#
#
# [CV] ..... max_features=log2, n_estimators=1000, max_depth=10 -42.3min[CV] ....... max_features=sqrt, n_estimators=100, max_depth=5 - 2.4min[CV] ....... max_features=sqrt, n_estimators=100, max_depth=5 - 2.3min[CV] ..... max_features=log2, n_estimators=1000, max_depth=10 -42.3min
#
#
#
# [CV] max_features=log2, n_estimators=1000, max_depth=5 ...............[CV] max_features=log2, n_estimators=100, max_depth=5 ................[CV] max_features=sqrt, n_estimators=100, max_depth=5 ................[CV] max_features=log2, n_estimators=100, max_depth=5 ................
#
#
#
# [CV] ...... max_features=log2, n_estimators=1000, max_depth=5 -23.7min[CV] ....... max_features=log2, n_estimators=100, max_depth=5 - 2.4min[CV] ....... max_features=sqrt, n_estimators=100, max_depth=5 - 2.4min[CV] ....... max_features=log2, n_estimators=100, max_depth=5 - 2.4min
#
#
#
# [CV] max_features=sqrt, n_estimators=1000, max_depth=10 ..............[CV] max_features=sqrt, n_estimators=1000, max_depth=5 ...............[CV] max_features=log2, n_estimators=100, max_depth=5 ................[CV] max_features=sqrt, n_estimators=1000, max_depth=5 ...............
#
#
#
# [CV] ..... max_features=sqrt, n_estimators=1000, max_depth=10 -35.3min[CV] ...... max_features=sqrt, n_estimators=1000, max_depth=5 -23.9min[CV] ....... max_features=log2, n_estimators=100, max_depth=5 - 2.4min[CV] ...... max_features=sqrt, n_estimators=1000, max_depth=5 -23.8min
#
#
#
# [CV] max_features=sqrt, n_estimators=100, max_depth=10 ...............[CV] max_features=sqrt, n_estimators=100, max_depth=10 ...............[CV] max_features=sqrt, n_estimators=1000, max_depth=5 ...............
#
#
# [CV] ...... max_features=sqrt, n_estimators=100, max_depth=10 - 4.2min[CV] ...... max_features=sqrt, n_estimators=100, max_depth=10 - 4.2min[CV] ...... max_features=sqrt, n_estimators=1000, max_depth=5 -23.7min
#
#
# [CV] max_features=auto, n_estimators=100, max_depth=5 ................[CV] max_features=auto, n_estimators=100, max_depth=5 ................[CV] max_features=sqrt, n_estimators=100, max_depth=10 ...............
#
#
# [CV] ....... max_features=auto, n_estimators=100, max_depth=5 - 7.9min[CV] ....... max_features=auto, n_estimators=100, max_depth=5 - 7.9min[CV] ...... max_features=sqrt, n_estimators=100, max_depth=10 - 4.2min
#
#
# [CV] max_features=log2, n_estimators=100, max_depth=10 ...............[CV] max_features=log2, n_estimators=1000, max_depth=5 ...............[CV] max_features=auto, n_estimators=100, max_depth=5 ................
#
#
# [CV] ...... max_features=log2, n_estimators=100, max_depth=10 - 4.3min[CV] ...... max_features=log2, n_estimators=1000, max_depth=5 -23.8min[CV] ....... max_features=auto, n_estimators=100, max_depth=5 - 7.9min
#
#
# [CV] max_features=log2, n_estimators=100, max_depth=10 ...............[CV] max_features=sqrt, n_estimators=1000, max_depth=10 ..............[CV] max_features=log2, n_estimators=1000, max_depth=5 ...............
#
#
# [CV] ...... max_features=log2, n_estimators=100, max_depth=10 - 4.3min[CV] ..... max_features=sqrt, n_estimators=1000, max_depth=10 -35.8min[CV] ...... max_features=log2, n_estimators=1000, max_depth=5 -23.8min
#
#
# [CV] max_features=log2, n_estimators=100, max_depth=10 ...............
# [CV] ...... max_features=log2, n_estimators=100, max_depth=10 - 4.3min
# [CV] max_features=sqrt, n_estimators=1000, max_depth=10 ..............
# [CV] ..... max_features=sqrt, n_estimators=1000, max_depth=10 -38.1min

# %%
print searchRF.best_estimator_
print searchRF.best_score_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=1000, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
# -0.105326616694

# %%
searchRF.grid_scores_
# Out:
# [mean: -0.13157, std: 0.00043, params: {'max_features': 'auto', 'n_estimators': 1000, 'max_depth': 5},
#  mean: -0.10555, std: 0.00013, params: {'max_features': 'log2', 'n_estimators': 1000, 'max_depth': 10},
#  mean: -0.13242, std: 0.00061, params: {'max_features': 'sqrt', 'n_estimators': 100, 'max_depth': 5},
#  mean: -0.13269, std: 0.00068, params: {'max_features': 'log2', 'n_estimators': 100, 'max_depth': 5},
#  mean: -0.13234, std: 0.00046, params: {'max_features': 'sqrt', 'n_estimators': 1000, 'max_depth': 5},
#  mean: -0.10562, std: 0.00022, params: {'max_features': 'sqrt', 'n_estimators': 100, 'max_depth': 10},
#  mean: -0.13158, std: 0.00043, params: {'max_features': 'auto', 'n_estimators': 100, 'max_depth': 5},
#  mean: -0.13237, std: 0.00050, params: {'max_features': 'log2', 'n_estimators': 1000, 'max_depth': 5},
#  mean: -0.10554, std: 0.00029, params: {'max_features': 'log2', 'n_estimators': 100, 'max_depth': 10},
#  mean: -0.10533, std: 0.00017, params: {'max_features': 'sqrt', 'n_estimators': 1000, 'max_depth': 10}]

# %%
searchRFpred = searchRF.predict(X_valid0)

# %%
rmspe(y_valid, searchRFpred)

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
params_gb = {'learning_rate': [0.1, 0.01],
              'max_depth': [8, 10],
              'subsample': [0.6, 0.8] 
              }

gb = GradientBoostingRegressor(n_estimators=1000)
searchRF = grid_search.RandomizedSearchCV(gb, params_gb, scoring='mean_squared_error', n_jobs=-1, verbose=2).fit(X_train0, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits

# %%
gb = GradientBoostingRegressor(n_estimators=1000, max_depth=10, subsample=0.9, verbose=1, warm_start=True)
gb.fit(X_train0, y_train)
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           0.1662           0.0146          339.41m
#          2           0.1538           0.0123          332.76m
#          3           0.1439           0.0099          329.85m
#          4           0.1358           0.0081          330.21m
#          5           0.1286           0.0070          330.53m
#          6           0.1227           0.0060          371.55m
#          7           0.1171           0.0053          379.09m
#          8           0.1123           0.0048          388.81m
#          9           0.1087           0.0034          381.89m
#         10           0.1055           0.0033          375.33m
#         20           0.0841           0.0009          605.91m
#         30           0.0695           0.0027          661.03m
#         40           0.0548           0.0021          624.17m
#         50           0.0480           0.0003          543.75m
#         60           0.0427           0.0005          485.89m
#         70           0.0361           0.0005          446.69m
#         80           0.0307           0.0004          416.45m
#         90           0.0274           0.0003          393.13m
#        100           0.0244           0.0001          374.14m
#        200           0.0113           0.0000          372.53m
#        300           0.0083           0.0000          322.14m
#        400           0.0069           0.0000          312.60m
#        500           0.0060           0.0000          236.74m
#        600           0.0053          -0.0000          202.25m
#        700           0.0048          -0.0000          142.64m
#        800           0.0044          -0.0000           96.82m
#        900           0.0040          -0.0000           46.46m
#       1000           0.0038          -0.0000            0.00s
# GradientBoostingRegressor(alpha=0.9, init=None, learning_rate=0.1, loss='ls',
#              max_depth=10, max_features=None, max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=1000,
#              random_state=None, subsample=0.9, verbose=1, warm_start=True)

# %%
test_dev, ax = deviance_plot(gb, X_valid0, y_valid)
ax.legend(loc='upper right')

# %%
gb_predTrain = gb.predict(X_train0)
rmspe_xg(y_train, gb_predTrain)
# Out:
# ('rmspe', 0.063314997334308926)

# %%
gb_pred = gb.predict(X_valid0)
rmspe_xg(y_valid, gb_pred)
# Out:
# ('rmspe', 0.10187279729057373)

# %%
X_test = newTest[features].values
test_pred = np.expm1(gb.predict(X_test))

# %%
result = pd.DataFrame({"Id": newTest["Id"], 'Sales': test_pred})
result.to_csv("Rossmann_Store_Sales.csv", index=False)
