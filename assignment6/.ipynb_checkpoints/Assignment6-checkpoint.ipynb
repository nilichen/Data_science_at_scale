# %%
import pandas as pd

# %%
sf = pd.read_csv("sanfrancisco_incidents_summer_2014.csv", index_col=0)

# %%
sf.head()
# Out:
#                  Category                      Descript DayOfWeek        Date  \
# IncidntNum
# 140734311           ARSON            ARSON OF A VEHICLE    Sunday  08/31/2014
# 140736317    NON-CRIMINAL                 LOST PROPERTY    Sunday  08/31/2014
# 146177923   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO    Sunday  08/31/2014
# 146177531   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO    Sunday  08/31/2014
# 140734220    NON-CRIMINAL                FOUND PROPERTY    Sunday  08/31/2014
#
#              Time PdDistrict Resolution                    Address  \
# IncidntNum
# 140734311   23:50    BAYVIEW       NONE  LOOMIS ST / INDUSTRIAL ST
# 140736317   23:45    MISSION       NONE     400 Block of CASTRO ST
# 146177923   23:30   SOUTHERN       NONE   1000 Block of MISSION ST
# 146177531   23:30   RICHMOND       NONE        FULTON ST / 26TH AV
# 140734220   23:23   RICHMOND       NONE   800 Block of LA PLAYA ST
#
# ...

# %%
seattle = pd.read_csv("seattle_incidents_summer_2014.csv", index_col=0)
# Out:
# /Users/KatrinaNi/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
seattle.head()
# Out:
#             General Offense Number Offense Code  Offense Code Extension  \
# RMS CDW ID
# 483839                  2015218538         2202                       0
# 481252                  2015213067         2610                       0
# 481375                  2015210301         2316                       0
# 481690                  2015209327         2599                       0
# 478198                  2015207880         2399                       3
#
#                     Offense Type Summary Offense Code  \
# RMS CDW ID
# 483839        BURGLARY-FORCE-RES                 2200
# 481252      FRAUD-IDENTITY THEFT                 2600
# 481375                THEFT-MAIL                 2300
# 481690               COUNTERFEIT                 2500
# 478198                 THEFT-OTH                 2300
#
#            Summarized Offense Description           Date Reported  \
# RMS CDW ID
# 483839                           BURGLARY  06/28/2015 10:31:00 AM
# ...

# %%
len(seattle)
# Out:
# 32779

# %%
len(sf)
# Out:
# 28993
